# %% [markdown]
# # Setup
# This IPython notebook will walk through the steps of characterizing iModulons through the semi-automated tools in PyModulon. You will need:
#
# * M and A matrices
# * Expression data (e.g. `log_tpm_norm.csv`)
# * Gene table and KEGG/GO annotations (Generated in `gene_annotation.ipynb`)
# * Sample table, with a column for `project` and `condition`
# * TRN file
#
# Optional:
# * iModulon table (if you already have some characterized iModulons)

# %%
from pymodulon.core import IcaData
from pymodulon.plotting import *
from os import path
import pandas as pd
import re
from Bio.KEGG import REST
from tqdm.notebook import tqdm

# %%
# Enter the location of your data here
work_dir = '/home/jovyan/work/'
data_dir = path.join(work_dir,'processed_data')

# GO and KEGG annotations are in the 'external' folder
external_data = path.join(work_dir,'external')

# %% [markdown]
# ## Check your sample table (i.e. metadata file)
# Your metadata file will probably have a lot of columns, most of which you may not care about. Feel free to save a secondary copy of your metadata file with only columns that seem relevant to you. The two most important columns are:
# 1. `project`
# 2. `condition`
#
# Make sure that these columns exist in your metadata file

# %%
df_metadata = pd.read_csv(path.join(data_dir,'metadata.tsv'),index_col=0,sep='\t')

for idx, row in df_metadata[df_metadata['treatment'].isnull()].iterrows():
    df_metadata.loc[idx, 'treatment'] = row.condition
df_metadata.drop('condition', axis=1, inplace=True)

# %%
#combine different values to create unique condition names
cat_cols = ['treatment', 'growth_phase', 'isolate', 'genetic_changes'] 

df_metadata['condition'] = df_metadata['base_media'].str.cat(df_metadata[cat_cols],sep=';')

# %%
df_metadata[['project','condition']].head()
# Out:
#                      project                               condition
# CM_1   CcpA CodY interaction               CA-MHB;Control;exp;JE2;WT
# CM_10  CcpA CodY interaction      CA-MHB;None;exp;JE2;marR_TF::bursa
# CM_11  CcpA CodY interaction         CA-MHB;None;exp;JE2;ilvA::bursa
# CM_12  CcpA CodY interaction         CA-MHB;None;exp;JE2;ilvA::bursa
# CM_13  CcpA CodY interaction  CA-MHB;2g/Lglucose;exp;JE2;ilvA::bursa

# %%
print(df_metadata.project.notnull().all())
print(df_metadata.condition.notnull().all())
# Out:
# True
# True

# %%
df_metadata.to_csv(path.join(data_dir,'metadata.tsv'),sep='\t')

# %% [markdown]
# ## Check your TRN

# %% [markdown]
# Each row of the TRN file represents a regulatory interaction.
# **Your TRN file must have the following columns:**
# 1. `regulator` - Name of regulator (`/` or `+` characters will be converted to `;`)
# 1. `gene_id` - Locus tag of gene being regulated
#
# The following columns are optional, but are helpful to have:
# 1. `regulator_id` - Locus tag of regulator
# 1. `gene_name` - Name of gene (can automatically update this using `name2num`)
# 1. `direction` - Direction of regulation ('+' for activation, '-' for repression, '?' or NaN for unknown)
# 1. `evidence` - Evidence of regulation (e.g. ChIP-exo, qRT-PCR, SELEX, Motif search)
# 1. `PMID` - Reference for regulation
#
# You may add any other columns that could help you. TRNs may be saved as either CSV or TSV files. See below for an example:

# %%
df_trn = pd.read_csv(path.join(external_data,'TRN.csv'))
df_trn.head()
# Out:
#   regulator   TF_id trn_type gene_name N315_gene_id            gene_id
# 0       Zur  SA1383       TF    SA2203       SA2203  USA300HOU_RS13055
# 1       Zur  SA1383       TF    SA0806       SA0806  USA300HOU_RS04685
# 2       Zur  SA1383       TF     rpsN2       SA1171  USA300HOU_RS06795
# 3       Zur  SA1383       TF     rpmG2       SAS042  USA300HOU_RS06790
# 4       Zur  SA1383       TF      znuC       SA1385  USA300HOU_RS08305

# %% [markdown]
# The `regulator` and `gene_id` must be filled in for each row

# %%
print(df_trn.regulator.notnull().all())
print(df_trn.gene_id.notnull().all())
# Out:
# True
# True

# %% [markdown]
# ## Load the data
# You're now ready to load your IcaData object!

# %%
ica_data = IcaData(M = path.join(data_dir,'M.csv'),
                   A = path.join(data_dir,'A.csv'),
                   X = path.join(data_dir,'log_tpm_norm.csv'),
                   gene_table = path.join(data_dir,'gene_info.csv'),
                   sample_table = path.join(data_dir,'metadata.tsv'),
                   trn = path.join(external_data,'TRN.csv'),
                   optimize_cutoff=True)
# Out:
# WARNING:root:The characters '+' and '/' are used for combining regulons and cannot be in regulator names. These characters will be replaced with ';'
# WARNING:root:The following genes are in the TRN but not in your M matrix: {' USA300HOU_1986', ' USA300HOU_1483', ' USA300HOU_1442', 'USA300HOU_RS06665', ' USA300HOU_1973', ' USA300HOU_1952', ' USA300HOU_2009', ' USA300HOU_1435', ' USA300HOU_1967', ' USA300HOU_1990', ' USA300HOU_0858', ' USA300HOU_0860', ' USA300HOU_1476', ' USA300HOU_1968', ' USA300HOU_1432', ' USA300HOU_1440', ' USA300HOU_1487', ' USA300HOU_0852', ' USA300HOU_1463', ' USA300HOU_1988', ' USA300HOU_2004', ' USA300HOU_1992', ' USA300HOU_1457', ' USA300HOU_1950', ' USA300HOU_1484', ' USA300HOU_1477', ' USA300HOU_1987', ' USA300HOU_1976', ' USA300HOU_1467', ' USA300HOU_1473', ' USA300HOU_1453', ' USA300HOU_1494', ' USA300HOU_0848', ' USA300HOU_2006', ' USA300HOU_1959', ' USA300HOU_1495', ' USA300HOU_1438', ' USA300HOU_1444', ' USA300HOU_1954', ' USA300HOU_1497', ' USA300HOU_2013', ' USA300HOU_1447', ' USA300HOU_1437', ' USA300HOU_1479', ' USA300HOU_1989', ' USA300HOU_1469', ' USA300HOU_1947', ' USA300HOU_1982', ' USA300HOU_1430', ' USA300HOU_1946', ' USA300HOU_1468', ' USA300HOU_2005', ' USA300HOU_1981', ' USA300HOU_1944', ' USA300HOU_1470', ' USA300HOU_1949', ' USA300HOU_1972', ' USA300HOU_1486', ' USA300HOU_1985', ' USA300HOU_1445', ' USA300HOU_1481', 'USA300HOU_RS10560', ' USA300HOU_1965', ' USA300HOU_1945', ' USA300HOU_1493', ' USA300HOU_1960', ' USA300HOU_2008', ' USA300HOU_1478', ' USA300HOU_2001', ' USA300HOU_1970', ' USA300HOU_1957', ' USA300HOU_1433', ' USA300HOU_1446', ' USA300HOU_1461', 'USA300HOU_RS10920', ' USA300HOU_1456', ' USA300HOU_1431', ' USA300HOU_1963', ' USA300HOU_1956', ' USA300HOU_1488', ' USA300HOU_1460', ' USA300HOU_1458', ' USA300HOU_1975', ' USA300HOU_1466', ' USA300HOU_1464', ' USA300HOU_1995', ' USA300HOU_1964', ' USA300HOU_1998', ' USA300HOU_1489', ' USA300HOU_1465', ' USA300HOU_1471', ' USA300HOU_2003', ' USA300HOU_0868', ' USA300HOU_1439', ' USA300HOU_1459', 'USA300HOU_RS09585', ' USA300HOU_0863', 'USA300HOU_RS10540', ' USA300HOU_0855', ' USA300HOU_2012', ' USA300HOU_1448', ' USA300HOU_0859', ' USA300HOU_1999', ' USA300HOU_1955', ' USA300HOU_1966', ' USA300HOU_1980', ' USA300HOU_1978', ' USA300HOU_1490', ' USA300HOU_0861', ' USA300HOU_1993', ' USA300HOU_1951', ' USA300HOU_0867', ' USA300HOU_1441', ' USA300HOU_1969', ' USA300HOU_1475', ' USA300HOU_1971', ' USA300HOU_1942', ' USA300HOU_0857', ' USA300HOU_0850', ' USA300HOU_1997', ' USA300HOU_1452', ' USA300HOU_1498', ' USA300HOU_0853', ' USA300HOU_1434', ' USA300HOU_1462', ' USA300HOU_0854', ' USA300HOU_1962', ' USA300HOU_2002', ' USA300HOU_0862', ' USA300HOU_0849', 'USA300HOU_RS07965', ' USA300HOU_1994', ' USA300HOU_1984', ' USA300HOU_0865', 'USA300HOU_RS09610', ' USA300HOU_0869', 'USA300HOU_RS12850', ' USA300HOU_1974', ' USA300HOU_0866', ' USA300HOU_1979', ' USA300HOU_1449', ' USA300HOU_1496', ' USA300HOU_1436', 'USA300HOU_RS00225', ' USA300HOU_1482', 'USA300HOU_RS06650', ' USA300HOU_1953', ' USA300HOU_1454', ' USA300HOU_1492', ' USA300HOU_0856', ' USA300HOU_1991', ' USA300HOU_2011', ' USA300HOU_0851', ' USA300HOU_1472', ' USA300HOU_1451', ' USA300HOU_1977', ' USA300HOU_0870', ' USA300HOU_0864', ' USA300HOU_1961', ' USA300HOU_1983', ' USA300HOU_1443', ' USA300HOU_1996', ' USA300HOU_1485', ' USA300HOU_0847', ' USA300HOU_2000', ' USA300HOU_2007', ' USA300HOU_1450', ' USA300HOU_1455', ' USA300HOU_1474', ' USA300HOU_1958'}
# WARNING:root:Optimizing iModulon thresholds, may take 2-3 minutes...

# %% [markdown]
# # Regulatory iModulons
# Use `compute_trn_enrichment` to automatically check for Regulatory iModulons. The more complete your TRN, the more regulatory iModulons you'll find.

# %%
ica_data.compute_trn_enrichment()
# Out:
#     imodulon         regulator        pvalue        qvalue  precision  \
# 0          1              FruR  0.000000e+00  0.000000e+00   1.000000
# 1          3              WalR  1.977615e-13  3.955230e-13   0.800000
# 2          5  Genomic Island 9  6.486677e-39  1.946003e-38   0.838710
# 3          5              VraR  3.907315e-06  5.860973e-06   0.193548
# 4          6            Purine  2.523321e-11  7.569963e-11   0.500000
# 5          9               TPP  0.000000e+00  0.000000e+00   1.000000
# 6         10              PurR  1.365061e-29  2.730122e-29   0.857143
# 7         11             VraS2  9.312770e-09  2.793831e-08   0.500000
# 8         13              CcpA  1.213330e-81  2.426660e-80   0.654545
# 9         13              MalR  1.341246e-13  1.341246e-12   0.081818
# 10        15              CggR  3.789150e-15  3.789150e-15   1.000000
# 11        17              CcpA  2.460824e-06  2.460824e-06   0.714286
# 12        20               Rex  1.656345e-07  8.281726e-07   0.179487
# 13        22               FMN  3.789150e-15  3.789150e-15   0.833333
# 55  0.101911  0.161616  16.0         157.0           41.0     1.0
# 56  0.049587  0.094488   6.0         121.0            6.0     1.0
# 57  0.095238  0.172840  14.0         147.0           15.0     1.0
# 58  0.444444  0.333333   4.0           9.0           15.0     1.0

# %% [markdown]
# You can also search for AND/OR combinations of regulators using the `max_regs` argument.
#
# Regulator enrichments can be directly saved to the `imodulon_table` using the `save` argument. This saves the enrichment with the lowest q-value to the table.

# %%
# First search for regulator enrichments with 2 regulators
ica_data.compute_trn_enrichment(max_regs=2,save=True)

# Next, search for regulator enrichments with just one regulator. This will supercede the 2 regulator enrichments.
ica_data.compute_trn_enrichment(max_regs=1,save=True)
# Out:
#     imodulon         regulator        pvalue        qvalue  precision  \
# 0          1              FruR  0.000000e+00  0.000000e+00   1.000000
# 1          3              WalR  1.977615e-13  3.955230e-13   0.800000
# 2          5  Genomic Island 9  6.486677e-39  1.946003e-38   0.838710
# 3          5              VraR  3.907315e-06  5.860973e-06   0.193548
# 4          6            Purine  2.523321e-11  7.569963e-11   0.500000
# 5          9               TPP  0.000000e+00  0.000000e+00   1.000000
# 6         10              PurR  1.365061e-29  2.730122e-29   0.857143
# 7         11             VraS2  9.312770e-09  2.793831e-08   0.500000
# 8         13              CcpA  1.213330e-81  2.426660e-80   0.654545
# 9         13              MalR  1.341246e-13  1.341246e-12   0.081818
# 10        15              CggR  3.789150e-15  3.789150e-15   1.000000
# 11        17              CcpA  2.460824e-06  2.460824e-06   0.714286
# 12        20               Rex  1.656345e-07  8.281726e-07   0.179487
# 13        22               FMN  3.789150e-15  3.789150e-15   0.833333
# 14        23              ArcR  0.000000e+00  0.000000e+00   1.000000
# 15        23              ArgR  2.758501e-12  5.517002e-12   1.000000
# 16        23               Rex  1.498836e-10  1.998448e-10   1.000000
# 17        23              CcpA  1.255425e-07  1.255425e-07   1.000000
# 18        24              PyrR  8.232349e-23  1.646470e-22   0.888889
# 19        24              WalR  1.832865e-06  1.832865e-06   0.666667
# 20        28  Genomic Island 3  2.803906e-19  5.607811e-19   0.625000
# 21        29              CodY  3.741945e-50  4.864528e-49   0.616279
# 22        29            Lysine  6.003517e-10  3.902286e-09   0.081395
# 23        29        T-box(Trp)  4.265891e-09  1.848553e-08   0.069767
# 24        29              HisR  2.594151e-08  6.744792e-08   0.081395
# 25        29        T-box(Met)  2.199368e-08  6.744792e-08   0.058140
# 26        31              CodY  1.987481e-12  1.987481e-12   1.000000
# 27        32              CtsR  2.899696e-26  8.699089e-26   1.000000
# 28        32              HrcA  9.534712e-13  1.430207e-12   0.500000
# 29        37              CymR  1.655744e-29  4.967233e-29   0.700000
# 30        38  Genomic Island 1  1.040356e-36  3.121069e-36   0.354839
# 31        39              AgrA  1.326202e-14  2.652405e-14   0.714286
# 32        40  Genomic Island 9  5.380175e-33  5.380175e-33   0.913043
# 33        41              HssR  0.000000e+00  0.000000e+00   1.000000
# 34        43  Genomic Island 9  5.602650e-16  2.241060e-15   0.785714
# 35        46              MntR  4.115537e-09  4.115537e-09   0.750000
# 36        48             VraS2  1.639155e-36  6.556622e-36   0.600000
# 37        48              VraR  1.401629e-24  2.803259e-24   0.450000
# 39  0.833333   5.0           5.0            7.0     1.0
# 40  0.432990  21.0          74.0           23.0     1.0
# 41  1.000000   2.0           2.0            2.0     1.0
# 43  0.250000  11.0          74.0           14.0     1.0
# 46  0.750000   3.0           4.0            4.0     1.0
# 48  0.564706  24.0          45.0           40.0     1.0
# 49  0.291667  28.0         157.0           35.0     1.0
# 50  1.000000  12.0          12.0           12.0     1.0
# 52  1.000000   2.0           2.0            2.0     1.0
# 54  0.168675  14.0         147.0           19.0     1.0
# 55  0.711538  37.0          47.0           57.0     1.0
# 58  0.833333   5.0           5.0            7.0     1.0
# 59  0.418605   9.0          33.0           10.0     1.0
# 62  0.315789   3.0           3.0           16.0     1.0
# 63  0.237885  27.0         157.0           70.0     1.0
# 65  0.211268  15.0         121.0           21.0     1.0
# 66  0.290909   8.0          47.0            8.0     1.0
# 67  0.363636   4.0          16.0            6.0     1.0
# 68  0.161616  16.0         157.0           41.0     1.0
# 69  0.094488   6.0         121.0            6.0     1.0
# 73  0.172840  14.0         147.0           15.0     1.0

# %% [markdown]
# You can rename iModulons in this jupyter notebook, or you can save the iModulon table as a CSV and edit it in Excel.
#
# If two iModulons have the same regulator (e.g. 'Reg'), they will be named 'Reg-1' and 'Reg-2'

# %%
ica_data.rename_imodulons(regulatory_imodulons.regulator.to_dict())
ica_data.imodulon_table.head()
# Out:
# WARNING:root:Duplicate iModulon names detected. iModulon 3 will be renamed to WalR-1
# WARNING:root:Duplicate iModulon names detected. iModulon 5 will be renamed to Genomic Island 9-1
# WARNING:root:Duplicate iModulon names detected. iModulon 11 will be renamed to VraS2-1
# WARNING:root:Duplicate iModulon names detected. iModulon 13 will be renamed to CcpA-1
# WARNING:root:Duplicate iModulon names detected. iModulon 17 will be renamed to CcpA-2
# WARNING:root:Duplicate iModulon names detected. iModulon 20 will be renamed to Rex-1
# WARNING:root:Duplicate iModulon names detected. iModulon 29 will be renamed to CodY-1
# WARNING:root:Duplicate iModulon names detected. iModulon 31 will be renamed to CodY-2
# WARNING:root:Duplicate iModulon names detected. iModulon 40 will be renamed to Genomic Island 9-2
# WARNING:root:Duplicate iModulon names detected. iModulon 43 will be renamed to Genomic Island 9-3
# WARNING:root:Duplicate iModulon names detected. iModulon 48 will be renamed to VraS2-2
# WARNING:root:Duplicate iModulon names detected. iModulon 49 will be renamed to WalR-2
# WARNING:root:Duplicate iModulon names detected. iModulon 54 will be renamed to CodY-3
# WARNING:root:Duplicate iModulon names detected. iModulon 55 will be renamed to Fur-1
# WARNING:root:Duplicate iModulon names detected. iModulon 59 will be renamed to Rex-2
# WARNING:root:Duplicate iModulon names detected. iModulon 63 will be renamed to WalR-3
# WARNING:root:Duplicate iModulon names detected. iModulon 65 will be renamed to CcpA-3
# WARNING:root:Duplicate iModulon names detected. iModulon 66 will be renamed to Fur-2
# WARNING:root:Duplicate iModulon names detected. iModulon 68 will be renamed to WalR-4
# WARNING:root:Duplicate iModulon names detected. iModulon 69 will be renamed to CcpA-4
# WARNING:root:Duplicate iModulon names detected. iModulon 73 will be renamed to CodY-4
#        regulator        pvalue        qvalue  precision    recall   f1score  \
# 0            NaN           NaN           NaN        NaN       NaN       NaN
# FruR        FruR  0.000000e+00  0.000000e+00        1.0  1.000000  1.000000
# 2            NaN           NaN           NaN        NaN       NaN       NaN
# WalR-1      WalR  1.977615e-13  3.955230e-13        0.8  0.076433  0.139535
# 4            NaN           NaN           NaN        NaN       NaN       NaN
#
#           TP  regulon_size  imodulon_size  n_regs
# 0        NaN           NaN            NaN     NaN
# FruR     3.0           3.0            3.0     1.0
# 2        NaN           NaN            NaN     NaN
# WalR-1  12.0         157.0           15.0     1.0
# 4        NaN           NaN            NaN     NaN

# %%
regulatory_imodulons = ica_data.imodulon_table[ica_data.imodulon_table.regulator.notnull()]

# %% [markdown]
# # Functional iModulons

# %% [markdown]
# GO annotations and KEGG pathways/modules were generated in the 1_create_the_gene_table.ipynb notebook. Enrichments will be calculated in this notebook, and further curated in the 3_manual_iModulon_curation notebook.

# %% [markdown]
# ## GO Enrichments

# %% [markdown]
# First load the Gene Ontology annotations

# %%
DF_GO = pd.read_csv(path.join(work_dir, 'external', 'eggNOG_annotations.txt'), sep='\t', skiprows=4)
DF_GO = DF_GO.rename(columns={'#query': 'gene_id'})

# %%
DF_GO_enrich = ica_data.compute_annotation_enrichment(DF_GO,'COG_category')

# %%
DF_GO_enrich.head()
# Out:
#              imodulon COG_category    pvalue    qvalue  precision    recall  \
# 0                   0            E  0.000829  0.051398   0.315789  0.032967
# 1              WalR-1            M  0.000045  0.002784   0.400000  0.042553
# 2  Genomic Island 9-1            S  0.000213  0.013219   0.516129  0.025890
# 3              Purine            F  0.000002  0.000117   0.625000  0.052632
# 4                 TPP            H  0.000760  0.047127   0.428571  0.036145
#
#     f1score    TP  target_set_size  imodulon_size
# 0  0.059701   6.0            182.0           19.0
# 1  0.076923   6.0            141.0           15.0
# 2  0.049307  16.0            618.0           31.0
# 3  0.097087   5.0             95.0            8.0
# 4  0.066667   3.0             83.0            7.0

# %% [markdown]
# ## KEGG Enrichments

# %% [markdown]
# ### Load KEGG mapping
# The `kegg_mapping.csv` file contains KEGG orthologies, pathways, modules, and reactions. Only pathways and modules are relevant to iModulon characterization.

# %%
DF_KEGG = pd.read_csv(path.join(external_data,'kegg_mapping.csv'),index_col=0)
print(DF_KEGG.database.unique())
DF_KEGG.head()
# Out:
# ['KEGG_ko' 'KEGG_Pathway' 'KEGG_Module' 'KEGG_Reaction']
#               gene_id database kegg_id
# 10  USA300HOU_RS00050  KEGG_ko       -
# 11  USA300HOU_RS00055  KEGG_ko       -
# 13  USA300HOU_RS00065  KEGG_ko       -
# 14  USA300HOU_RS00070  KEGG_ko       -
# 20  USA300HOU_RS00110  KEGG_ko       -

# %%
kegg_pathways = DF_KEGG[DF_KEGG.database == 'KEGG_Pathway']
kegg_modules = DF_KEGG[DF_KEGG.database == 'KEGG_Module']

# %% [markdown]
# ### Perform enrichment
# Uses the `compute_annotation_enrichment` function

# %%
DF_pathway_enrich = ica_data.compute_annotation_enrichment(kegg_pathways,'kegg_id')
DF_module_enrich = ica_data.compute_annotation_enrichment(kegg_modules,'kegg_id')

# %%
DF_pathway_enrich.head()
# Out:
#   imodulon   kegg_id        pvalue    qvalue  precision    recall   f1score  \
# 0        0  map00791  2.493127e-07  0.000050   0.157895  1.000000  0.272727
# 1        0  map00220  3.073765e-04  0.030584   0.157895  0.142857  0.150000
# 2     FruR  map00051  9.958511e-05  0.019817   0.666667  0.117647  0.200000
# 3        4  map00260  3.619166e-04  0.072021   0.666667  0.062500  0.114286
# 4   Purine  map00230  1.695523e-05  0.003374   0.500000  0.060606  0.108108
#
#     TP  target_set_size  imodulon_size
# 0  3.0              3.0           19.0
# 1  3.0             21.0           19.0
# 2  2.0             17.0            3.0
# 3  2.0             32.0            3.0
# 4  4.0             66.0            8.0

# %% [markdown]
# ### Convert KEGG IDs to human-readable names

# %%
for idx,key in tqdm(DF_pathway_enrich.kegg_id.items(),total=len(DF_pathway_enrich)):
    text = REST.kegg_find('pathway',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_pathway_enrich.loc[idx,'pathway_name'] = name
    except AttributeError:
        DF_pathway_enrich.loc[idx,'pathway_name'] = None
    
for idx,key in tqdm(DF_module_enrich.kegg_id.items(),total=len(DF_module_enrich)):
    text = REST.kegg_find('module',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_module_enrich.loc[idx,'module_name'] = name
    except AttributeError:
        DF_module_enrich.loc[idx,'module_name'] = None
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]

# %%
DF_pathway_enrich.head()
# Out:
#   imodulon   kegg_id        pvalue    qvalue  precision    recall   f1score  \
# 0        0  map00791  2.493127e-07  0.000050   0.157895  1.000000  0.272727
# 1        0  map00220  3.073765e-04  0.030584   0.157895  0.142857  0.150000
# 2     FruR  map00051  9.958511e-05  0.019817   0.666667  0.117647  0.200000
# 3        4  map00260  3.619166e-04  0.072021   0.666667  0.062500  0.114286
# 4   Purine  map00230  1.695523e-05  0.003374   0.500000  0.060606  0.108108
#
#     TP  target_set_size  imodulon_size  \
# 0  3.0              3.0           19.0
# 1  3.0             21.0           19.0
# 2  2.0             17.0            3.0
# 3  2.0             32.0            3.0
# 4  4.0             66.0            8.0
#
#                                pathway_name
# 0                      Atrazine degradation
# 1                     Arginine biosynthesis
# 2           Fructose and mannose metabolism
# 3  Glycine, serine and threonine metabolism
# 4                         Purine metabolism

# %%
DF_module_enrich.head()
# Out:
#   imodulon kegg_id        pvalue        qvalue  precision    recall   f1score  \
# 0        4  M00555  7.348163e-07  1.873782e-04   0.666667  1.000000  0.800000
# 1   Purine  M00050  6.829507e-05  1.741524e-02   0.250000  0.400000  0.307692
# 2        7  M00725  8.801943e-10  2.244495e-07   0.571429  0.500000  0.533333
# 3      TPP  M00127  9.005102e-09  2.296301e-06   0.428571  1.000000  0.600000
# 4      TPP  M00582  2.548499e-06  3.249336e-04   0.428571  0.230769  0.300000
#
#     TP  target_set_size  imodulon_size  \
# 0  2.0              2.0            3.0
# 1  2.0              5.0            8.0
# 2  4.0              8.0            7.0
# 3  3.0              3.0            7.0
# 4  3.0             13.0            7.0
#
#                                          module_name
# 0           Betaine biosynthesis, choline => betaine
# 1  Guanine ribonucleotide biosynthesis, IMP => GD...
# 2  Cationic antimicrobial peptide (CAMP) resistan...
# 3  Thiamine biosynthesis, prokaryotes, AIR (+ DXP...
# 4                                               None

# %% [markdown]
# ## Save files

# %%
DF_GO_enrich['source'] = 'EggNOG'
DF_pathway_enrich['source'] = 'KEGG pathways'
DF_module_enrich['source'] = 'KEGG modules'

DF_GO_enrich.rename({'COG_category':'annotation'},axis=1, inplace=True)
DF_pathway_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)
DF_module_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)

DF_enrichments = pd.concat([DF_pathway_enrich, DF_module_enrich])
DF_enrichments.to_csv(path.join(data_dir,'functional_enrichments.csv'))

# %% [markdown]
# # Check for single gene iModulons

# %% [markdown]
# Some iModulons are dominated by a single, high-coefficient gene. These iModulons may result from:
# 1. Overdecomposition of the dataset to identify noisy genes
# 1. Artificial knock-out of single genes
# 1. Regulons with only one target gene
#
# No matter what causes these iModulons, it is important to be aware of them. The find_single_gene_imodulons function identifies iModulons that are likely dominated by a single gene.
#
# The iModulons identified by ``find_single_gene_imodulons`` may contain more than one gene, since a threshold-agnostic method is used to identify these iModulons.

# %%
sg_imods = ica_data.find_single_gene_imodulons(save=True)
len(sg_imods)
# Out:
# 8

# %%
for i,mod in enumerate(sg_imods):
    ica_data.rename_imodulons({mod:'SG_'+str(i+1)})

# %%
ica_data.imodulon_table[ica_data.imodulon_table.single_gene == True]
# Out:
#      regulator  pvalue  qvalue  precision  recall  f1score  TP  regulon_size  \
# SG_1       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_2       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_3       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_4       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_5       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_6       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_7       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
# SG_8       NaN     NaN     NaN        NaN     NaN      NaN NaN           NaN
#
#       imodulon_size  n_regs single_gene
# SG_1            NaN     NaN        True
# SG_2            NaN     NaN        True
# SG_3            NaN     NaN        True
# SG_4            NaN     NaN        True
# SG_5            NaN     NaN        True
# SG_6            NaN     NaN        True
# SG_7            NaN     NaN        True
# SG_8            NaN     NaN        True

# %% [markdown]
# # Save iModulon object

# %%
from pymodulon.util import explained_variance
from pymodulon.io import *

# %%
# Add iModulon sizes and explained variance
for im in ica_data.imodulon_names:
    ica_data.imodulon_table.loc[im,'imodulon_size'] = len(ica_data.view_imodulon(im))
    ica_data.imodulon_table.loc[im,'explained_variance'] = explained_variance(ica_data,imodulons=im)

# %% [markdown]
# This will save your iModulon table, your thresholds, and any other information stored in the ica_data object.

# %%
save_to_json(ica_data, path.join(work_dir,'interim','saureus_raw.json.gz'))

# %% [markdown]
# If you prefer to view and edit your iModulon table in excel, save it as a CSV and reload the iModulon as before

# %%
ica_data.imodulon_table.to_csv(path.join(data_dir,'imodulon_table_raw.csv'))
